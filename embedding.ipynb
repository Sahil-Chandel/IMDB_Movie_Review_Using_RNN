# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From e:\ML\19.1 RNN Classification\Simple RNN\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %% [markdown]
# ## Define  the vocubulary Size

# %%
voc_size = 10000

# %% [markdown]
# ## One Hot Representation

# %%
one_hot_repr = [one_hot(words, voc_size)for words in sent]
one_hot_repr
# Out:
# [[6988, 4970, 1966, 8067],
#  [6988, 4970, 1966, 1032],
#  [6988, 1093, 1966, 4477],
#  [2291, 3166, 1634, 5327, 3987],
#  [2291, 3166, 1634, 5327, 9327],
#  [2365, 6988, 4392, 1966, 8553],
#  [3801, 8555, 8694, 5327]]

# %% [markdown]
# ## Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length) 
print(embedded_docs)
# Out:
# [[   0    0    0    0 6988 4970 1966 8067]
#  [   0    0    0    0 6988 4970 1966 1032]
#  [   0    0    0    0 6988 1093 1966 4477]
#  [   0    0    0 2291 3166 1634 5327 3987]
#  [   0    0    0 2291 3166 1634 5327 9327]
#  [   0    0    0 2365 6988 4392 1966 8553]
#  [   0    0    0    0 3801 8555 8694 5327]]

# %% [markdown]
# ## Feature Representation

# %%
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From e:\ML\19.1 RNN Classification\Simple RNN\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From e:\ML\19.1 RNN Classification\Simple RNN\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 126ms/step
# array([[[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.02283517, -0.01029612,  0.01915015,  0.03055134,
#          -0.02530191,  0.01617182,  0.01779082, -0.00337905,
#          -0.00941082, -0.00814991],
#         [ 0.03230735,  0.00966555, -0.03455421,  0.04287872,
#           0.00254955, -0.03111886,  0.00301398,  0.02327467,
#          -0.04759751,  0.04288954],
#         [ 0.02543527,  0.03567067, -0.04612077, -0.0382951 ,
#          -0.0480343 , -0.03195028, -0.03950446, -0.04517749,
#           0.0056937 ,  0.02966816],
#         [ 0.02633283,  0.03151038,  0.01632876,  0.01471026,
#           0.0276336 ,  0.02491106, -0.00260072, -0.03333642,
#          -0.04814908, -0.04707536]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.02283517, -0.01029612,  0.01915015,  0.03055134,
#          -0.02530191,  0.01617182,  0.01779082, -0.00337905,
#          -0.00941082, -0.00814991],
#         [ 0.03230735,  0.00966555, -0.03455421,  0.04287872,
#           0.00254955, -0.03111886,  0.00301398,  0.02327467,
#          -0.04759751,  0.04288954],
#         [ 0.02543527,  0.03567067, -0.04612077, -0.0382951 ,
#          -0.0480343 , -0.03195028, -0.03950446, -0.04517749,
#           0.0056937 ,  0.02966816],
#         [ 0.04360491, -0.00175942,  0.00952122,  0.02408414,
#           0.03293847,  0.00136002, -0.02376745, -0.04550833,
#          -0.04968871, -0.03859446]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.02283517, -0.01029612,  0.01915015,  0.03055134,
#          -0.02530191,  0.01617182,  0.01779082, -0.00337905,
#          -0.00941082, -0.00814991],
#         [ 0.04008729,  0.04682526, -0.03362709, -0.02546719,
#          -0.03446429,  0.01663664,  0.03458384,  0.01636909,
#           0.04629985,  0.03188899],
#         [ 0.02543527,  0.03567067, -0.04612077, -0.0382951 ,
#          -0.0480343 , -0.03195028, -0.03950446, -0.04517749,
#           0.0056937 ,  0.02966816],
#         [ 0.03318224,  0.00612725, -0.01366825, -0.04579878,
#           0.00119091, -0.04663103,  0.01838655,  0.01697389,
#          -0.04199366,  0.00031336]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [-0.0238909 ,  0.02708242, -0.04563365,  0.03435013,
#           0.03733372,  0.00147349, -0.03300178, -0.00601231,
#           0.04513011, -0.01705729],
#         [-0.00087957, -0.01485503,  0.00800186, -0.01272341,
#          -0.00628102, -0.04295207,  0.04641179,  0.02447325,
#          -0.01129369, -0.01853746],
#         [-0.04959778, -0.03098801, -0.04947593,  0.04654123,
#           0.00080096, -0.0177567 ,  0.00869018, -0.04393056,
#          -0.00586482, -0.04857619],
#         [ 0.02465362, -0.0021831 , -0.03910286,  0.03677118,
#           0.036169  , -0.00245588, -0.02234249, -0.03282961,
#           0.01428697,  0.03872538],
#         [-0.04618964,  0.02652439,  0.00338665, -0.00696069,
#           0.00304762,  0.00745416, -0.02536957,  0.00063971,
#           0.03501343,  0.00457967]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [-0.0238909 ,  0.02708242, -0.04563365,  0.03435013,
#           0.03733372,  0.00147349, -0.03300178, -0.00601231,
#           0.04513011, -0.01705729],
#         [-0.00087957, -0.01485503,  0.00800186, -0.01272341,
#          -0.00628102, -0.04295207,  0.04641179,  0.02447325,
#          -0.01129369, -0.01853746],
#         [-0.04959778, -0.03098801, -0.04947593,  0.04654123,
#           0.00080096, -0.0177567 ,  0.00869018, -0.04393056,
#          -0.00586482, -0.04857619],
#         [ 0.02465362, -0.0021831 , -0.03910286,  0.03677118,
#           0.036169  , -0.00245588, -0.02234249, -0.03282961,
#           0.01428697,  0.03872538],
#         [ 0.03831693,  0.01283253, -0.04805012, -0.01567649,
#          -0.01770974,  0.03158451,  0.01283697,  0.03822127,
#          -0.03924949,  0.02133738]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [-0.01794624,  0.00735146,  0.02532971,  0.00874106,
#           0.03174726,  0.04107127,  0.02132617, -0.03437132,
#           0.0314829 , -0.03141432],
#         [ 0.02283517, -0.01029612,  0.01915015,  0.03055134,
#          -0.02530191,  0.01617182,  0.01779082, -0.00337905,
#          -0.00941082, -0.00814991],
#         [-0.04054065,  0.04455935, -0.0261813 , -0.02140938,
#           0.04337554,  0.04677748, -0.00982282,  0.00878835,
#           0.00159715, -0.04521866],
#         [ 0.02543527,  0.03567067, -0.04612077, -0.0382951 ,
#          -0.0480343 , -0.03195028, -0.03950446, -0.04517749,
#           0.0056937 ,  0.02966816],
#         [-0.02232864, -0.04373628, -0.03701602,  0.01778562,
#          -0.04564355, -0.01412209, -0.01606057, -0.01412041,
#           0.00792152, -0.04252824]],
#
#        [[ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.04888551, -0.02637707,  0.02708841,  0.03318037,
#          -0.00105094, -0.02917389, -0.01120576, -0.04851923,
#          -0.00147323,  0.02310618],
#         [ 0.00642511, -0.00205966, -0.02119275,  0.03844848,
#           0.04270015,  0.02855264,  0.01646957,  0.00387228,
#           0.0361685 , -0.00829478],
#         [-0.01205667, -0.00558039, -0.03349509,  0.04198021,
#          -0.04693725, -0.03736382, -0.02827711,  0.00922535,
#           0.04452423,  0.02820105],
#         [-0.00910807,  0.02394303,  0.00734718,  0.0429343 ,
#          -0.0069196 , -0.02188008, -0.04999247,  0.04781904,
#          -0.01388265,  0.01546056],
#         [ 0.02465362, -0.0021831 , -0.03910286,  0.03677118,
#           0.036169  , -0.00245588, -0.02234249, -0.03282961,
#           0.01428697,  0.03872538]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 6988, 4970, 1966, 8067])
